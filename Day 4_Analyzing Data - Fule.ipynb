# %%
import pandas as pd
import numpy as np
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
#To show all my data, use pd.set_option('display.max_rows', None)

# %%
df.info() #displays the data type and
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    float64
#  10  Payment ID        244 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 21.1+ KB

# %%
ls   #listing of files in my directory
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is E696-83E1
#
#  Directory of C:\Users\Manyi\Documents\BlackTECH Python Class
#
#
#  Directory of C:\Users\Manyi\Documents\BlackTECH Python Class
#
#
#  Directory of C:\Users\Manyi\Documents\BlackTECH Python Class
#
#
#  Directory of C:\Users\Manyi\Documents\BlackTECH Python Class
#
#
#  Directory of C:\Users\Manyi\Documents\BlackTECH Python Class
#
#
#  Directory of C:\Users\Manyi\Documents\BlackTECH Python Class
# File Not Found

# %%
pwd   #location of data file
# Out:
# 'C:\\Users\\Manyi\\Documents\\BlackTECH Python Class'

# %%
len(df) #number of rows
# Out:
# 244

# %%
df.head(10)    #displays top 10
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 7       26.88  3.12    Male     No  Sun  Dinner     4              6.72
# 8       15.04  1.96    Male     No  Sun  Dinner     2              7.52
# 9       14.78  3.23    Male     No  Sun  Dinner     2              7.39
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1      Douglas Tucker  4.478070e+15    Sun4608
# ...

# %%
df.tail(10)   #displays last 10
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name     CC Number Payment ID
# 234    Tracy Douglas  4.097940e+15    Sat7220
# 235    Sean Gonzalez  3.534021e+15    Sat4615
# ...

# %%
df.tail()   #displays last 5
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name     CC Number Payment ID
# 239    Michael Avila  5.296069e+15    Sat2657
# 240   Monica Sanders  3.506806e+15    Sat1766
# 241       Keith Wong  6.011892e+15    Sat3880
# 242     Dennis Dixon  4.375221e+12      Sat17
# 243  Michelle Hardin  3.511452e+15    Thur672

# %%
df['total_bill'].head()     #Accessing single column
# Out:
# 0    16.99
# 1    10.34
# 2    21.01
# 3    23.68
# 4    24.59
# Name: total_bill, dtype: float64

# %%
df[['total_bill','tip']].head()    #Displaying 2 columns (2-dimensional array)
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
df[['total_bill','tip','sex']].head()
# Out:
#    total_bill   tip     sex
# 0       16.99  1.01  Female
# 1       10.34  1.66    Male
# 2       21.01  3.50    Male
# 3       23.68  3.31    Male
# 4       24.59  3.61  Female

# %%
#Adding new column called tip_percent

df['tip_percent'] = (df['tip']/df['total_bill'])*100
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID  tip_percent
# 0  Christy Cunningham  3.560330e+15    Sun2959     5.944673
# 1      Douglas Tucker  4.478070e+15    Sun4608    16.054159
# 2      Travis Walters  6.011812e+15    Sun4458    16.658734
# 3    Nathaniel Harris  4.676138e+15    Sun5260    13.978041
# 4        Tonya Carter  4.832733e+15    Sun2251    14.680765

# %%
#Rounding up to 2 decimal places
df['tip_percent'] = np.round((df['tip']/df['total_bill'])*100, 2)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID  tip_percent
# ...

# %%
#Alternatively, Rounding up to 1 decimal place
df['tip_percent'] = ((df['tip']/df['total_bill'])*100).round(1)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID  tip_percent
# 0  Christy Cunningham  3.560330e+15    Sun2959          5.9
# 1      Douglas Tucker  4.478070e+15    Sun4608         16.1
# 2      Travis Walters  6.011812e+15    Sun4458         16.7
# 3    Nathaniel Harris  4.676138e+15    Sun5260         14.0
# 4        Tonya Carter  4.832733e+15    Sun2251         14.7

# %%
#Deleting a column temporarilly
df = df.drop('tip_percent', axis=1)   #NB: Column axis =1 & Row axis =0

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
#Deleting a column permanently
df = df.drop('tip_percent', axis=1)   #NB: Column axis =1 & Row axis =0
df

# %%
#Accessing Single row
df.loc[3]
# Out:
# total_bill                       23.68
# tip                               3.31
# sex                               Male
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                 11.84
# Payer Name            Nathaniel Harris
# CC Number           4676137647685994.0
# Payment ID                     Sun5260
# Name: 3, dtype: object

# %%
#Accessing multiple rows
df.loc[1:3].head()
# Out:
#    total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1       10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31  Male     No  Sun  Dinner     2             11.84
#
#          Payer Name     CC Number Payment ID
# 1    Douglas Tucker  4.478070e+15    Sun4608
# 2    Travis Walters  6.011812e+15    Sun4458
# 3  Nathaniel Harris  4.676138e+15    Sun5260

# %%
#Accessing multiple interspaced columns
df.loc[[5,9,17,20]]
# Out:
#     total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 5        25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 9        14.78  3.23  Male     No  Sun  Dinner     2              7.39
# 17       16.29  3.71  Male     No  Sun  Dinner     3              5.43
# 20       17.92  4.08  Male     No  Sat  Dinner     2              8.96
#
#        Payer Name     CC Number Payment ID
# 5      Erik Smith  2.131404e+14    Sun9679
# 9   Jerome Abbott  3.532125e+15    Sun3775
# 17   John Pittman  6.521340e+15    Sun2998
# 20    Thomas Rice  4.403296e+15    Sat1709

# %%
#Accessing multiple columns that are interspaced uniformly
df.loc[5:50:5]
# Out:
#     total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 5        25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 10       10.27  1.71  Male     No  Sun  Dinner     2              5.14
# 15       21.58  3.92  Male     No  Sun  Dinner     2             10.79
# 20       17.92  4.08  Male     No  Sat  Dinner     2              8.96
# 25       17.81  2.34  Male     No  Sat  Dinner     4              4.45
# 30        9.55  1.45  Male     No  Sat  Dinner     2              4.78
# 35       24.06  3.60  Male     No  Sat  Dinner     3              8.02
# 40       16.04  2.24  Male     No  Sat  Dinner     3              5.35
# 45       18.29  3.00  Male     No  Sun  Dinner     2              9.14
# 50       12.54  2.50  Male     No  Sun  Dinner     2              6.27
#
#             Payer Name     CC Number Payment ID
# 5           Erik Smith  2.131404e+14    Sun9679
# 10       William Riley  5.662876e+11    Sun2546
# ...

# %%
#Adding new row
sample_data = df.loc[0]

# %%
df.append(sample_data)     #This does not make a permanent change to the table (df) because it was not assigneddf.
# Out:
# C:\Users\Manyi\AppData\Local\Temp\ipykernel_2596\420836140.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(sample_data)
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
df.drop(243)  #delete row 243 temporarily
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name     CC Number Payment ID
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
#Conditional filtering
df['total_bill'] > 30
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'] > 30]   #To view entries
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 11        35.26   5.00  Female     No   Sun  Dinner     4              8.82
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 39        31.27   5.00    Male     No   Sat  Dinner     3             10.42
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 56        38.01   3.00    Male    Yes   Sat  Dinner     4              9.50
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 83        32.68   5.00    Male    Yes  Thur   Lunch     2             16.34
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# ...

# %%
(df['sex'] == 'Female') & (df['day'] == 'Sat')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240     True
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
df[(df['sex'] == 'Female') & (df['day'] == 'Sat')]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 21        20.29  2.75  Female     No  Sat  Dinner     2             10.14
# 22        15.77  2.23  Female     No  Sat  Dinner     2              7.88
# 29        19.65  3.00  Female     No  Sat  Dinner     2              9.82
# 32        15.06  3.00  Female     No  Sat  Dinner     2              7.53
# 33        20.69  2.45  Female     No  Sat  Dinner     4              5.17
# 37        16.93  3.07  Female     No  Sat  Dinner     3              5.64
# 57        26.41  1.50  Female     No  Sat  Dinner     2             13.20
# 66        16.45  2.47  Female     No  Sat  Dinner     2              8.22
# 67         3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 71        17.07  3.00  Female     No  Sat  Dinner     3              5.69
# 72        26.86  3.14  Female    Yes  Sat  Dinner     2             13.43
# 73        25.28  5.00  Female    Yes  Sat  Dinner     2             12.64
# ...

# %%
df[(df['day'] == 'Sat') | (df['day'] == 'Sun')] #display rows with day = Saturday or Sunday
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name     CC Number Payment ID
# ...

# %%
df[df['day'].isin(['Sat','Sun'])] #alternatively
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name     CC Number Payment ID
# ...

# %%
def last_four(x):         #To show only the last 4 digits of CC Number
    return str(x)[-4:]

# %%
#NB. ALWAYS TEST NEW FUNCTION FIRST BEFORE APPLYING IT TO DATA
info = '12345678911111123453333'

# %%
last_four(12345678911111123453333)
# Out:
# '3333'

# %%
df['cc'] = df['CC Number'].apply(last_four)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID    cc
# ...

# %%
#Distinguish values that below 2, between 2 and 5, and above 5

def tip_rate(x):
    if x <= 2:
        return '*'
    elif x > 2 and x < 5:
        return '**'
    else:
        return '***'

# %%
#Verify new function

tip_rate(6)
# Out:
# '***'

# %%
df['tip_r'] = df['tip'].apply(tip_rate)
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID    cc tip_r
# ...

# %%
df[df['tip'] > 5]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
# 116       29.93   5.07    Male     No   Sun  Dinner     4              7.48
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 155       29.85   5.14  Female     No   Sun  Dinner     5              5.97
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# ...

# %%
#Handling missing data      #NaN: Not a Number

#Import New Data
df = pd.read_csv('movie_scores.csv')
df
# Out:
#   first_name last_name   age  sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0    m              8.0              10.0
# 1        NaN       NaN   NaN  NaN              NaN               NaN
# 2       Hugh   Jackman  51.0    m              NaN               NaN
# 3      Oprah   Winfrey  66.0    f              6.0               8.0
# 4       Emma     Stone  31.0    f              7.0               9.0

# %%
df.describe()
# Out:
#             age  pre_movie_score  post_movie_score
# count   4.00000              3.0               3.0
# mean   52.75000              7.0               9.0
# std    15.88238              1.0               1.0
# min    31.00000              6.0               8.0
# 25%    46.00000              6.5               8.5
# 50%    57.00000              7.0               9.0
# 75%    63.75000              7.5               9.5
# max    66.00000              8.0              10.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   first_name        4 non-null      object
#  1   last_name         4 non-null      object
#  2   age               4 non-null      float64
#  3   sex               4 non-null      object
#  4   pre_movie_score   3 non-null      float64
#  5   post_movie_score  3 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 368.0+ bytes

# %%
df.isnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0       False      False  False  False            False             False
# 1        True       True   True   True             True              True
# 2       False      False  False  False             True              True
# 3       False      False  False  False            False             False
# 4       False      False  False  False            False             False

# %%
df.notnull()
# Out:
#    first_name  last_name    age    sex  pre_movie_score  post_movie_score
# 0        True       True   True   True             True              True
# 1       False      False  False  False            False             False
# 2        True       True   True   True            False             False
# 3        True       True   True   True             True              True
# 4        True       True   True   True             True              True

# %%
df['first_name'].notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: first_name, dtype: bool

# %%
df[df['first_name'].notnull()]
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 2       Hugh   Jackman  51.0   m              NaN               NaN
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
df[df['first_name'].isnull()]
# Out:
#   first_name last_name  age  sex  pre_movie_score  post_movie_score
# 1        NaN       NaN  NaN  NaN              NaN               NaN

# %%
#handlding missing data using mean

df['pre_movie_score'].fillna('empty')
# Out:
# 0      8.0
# 1    empty
# 2    empty
# 3      6.0
# 4      7.0
# Name: pre_movie_score, dtype: object

# %%
df['pre_movie_score'].fillna(df['pre_movie_score'].mean())
# Out:
# 0    8.0
# 1    7.0
# 2    7.0
# 3    6.0
# 4    7.0
# Name: pre_movie_score, dtype: float64

# %%
df['pre_movie_score'].mean()
# Out:
# 7.0

# %%
#Remove missing data (na= not available)
df.dropna()
# Out:
#   first_name last_name   age sex  pre_movie_score  post_movie_score
# 0        Tom     Hanks  63.0   m              8.0              10.0
# 3      Oprah   Winfrey  66.0   f              6.0               8.0
# 4       Emma     Stone  31.0   f              7.0               9.0

# %%
#Grouping Data

data = pd.read_csv('mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.groupby('model_year').mean()
# Out:
#                   mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
# 75          20.266667   5.600000    205.533333  3176.800000     16.050000
# 76          21.573529   5.647059    197.794118  3078.735294     15.941176
# 77          23.375000   5.464286    191.392857  2997.357143     15.435714
# 78          24.061111   5.361111    177.805556  2861.805556     15.805556
# 79          25.093103   5.827586    206.689655  3055.344828     15.813793
# 80          33.696552   4.137931    115.827586  2436.655172     16.934483
# ...

# %%
data.groupby('model_year').sum()
# Out:
#               mpg  cylinders  displacement  weight  acceleration  origin
# model_year
# 70          513.0        196        8161.0   97811         375.5      38
# 71          595.0        156        5873.0   83872         424.0      40
# 72          524.0        163        6114.5   90656         423.5      43
# 73          684.0        255       10275.0  136761         572.5      55
# 74          613.0        142        4637.0   77704         437.5      45
# 75          608.0        168        6166.0   95304         481.5      44
# 76          733.5        192        6725.0  104677         542.0      50
# 77          654.5        153        5359.0   83926         432.2      44
# 78          866.2        193        6401.0  103025         569.0      58
# 79          727.7        169        5994.0   88605         458.6      37
# 80          977.2        120        3359.0   70663         491.1      64
# 81          879.7        134        3924.0   73165         472.9      57
# ...

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
#Average mpg per year per cylinder count
data.groupby(['model_year', 'cylinders']).sum()
# Out:
#                         mpg  displacement  weight  acceleration  origin
# model_year cylinders
# 70         4          177.0         749.0   16048         112.0      16
#            6           82.0         796.0   10842          62.0       4
#            8          254.0        6616.0   70921         201.5      18
# 71         4          357.0        1324.0   26733         220.5      25
#            6          144.0        1947.0   25375         118.0       8
#            8           94.0        2602.0   31764          85.5       7
# 72         3           19.0          70.0    2330          13.5       3
#            4          328.0        1561.5   33357         241.0      27
#            8          177.0        4483.0   54969         169.0      13
# 73         3           18.0          70.0    2124          13.5       3
#            4          250.0        1202.0   25719         188.5      22
#            6          152.0        1698.0   23337         125.5      10
# ...

# %%
data.agg(['sum', 'mean'])[['mpg', 'weight']]
# Out:
# C:\Users\Manyi\AppData\Local\Temp\ipykernel_2596\240920245.py:1: FutureWarning: ['horsepower', 'name'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   data.agg(['sum', 'mean'])[['mpg', 'weight']]
#               mpg        weight
# sum   9358.800000  1.182229e+06
# mean    23.514573  2.970425e+03

# %%
#This dataset will be used for Homework #4
#Q1. Find the total score for each student
#Q2. Find the percentage total score for each student
#Q3. Grade the students eg. Grade A, B, C & D
info = pd.read_csv('student.csv')
info
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Comboning Data
import numpy as np
import pandas as pd
data_one = {'A':['A0','A1','A2','A3'], 'B':['B0','B1','B2','B3']}
data_two = {'C':['C0','C1','C2','C3'], 'D':['D0','D1','D2','D3']}

# %%
one = pd.DataFrame(data_one)
two = pd.DataFrame(data_two)
one
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
two
# Out:
#     C   D
# 0  C0  D0
# 1  C1  D1
# 2  C2  D2
# 3  C3  D3

# %%
#Combine one and two using Concat - Concatenate along Rows
axis_data = pd.concat([one,two], axis=0)
axis_data
# Out:
#      A    B    C    D
# 0   A0   B0  NaN  NaN
# 1   A1   B1  NaN  NaN
# 2   A2   B2  NaN  NaN
# 3   A3   B3  NaN  NaN
# 0  NaN  NaN   C0   D0
# 1  NaN  NaN   C1   D1
# 2  NaN  NaN   C2   D2
# 3  NaN  NaN   C3   D3

# %%
#Combine one and two using Concat - Concatenate along Columns
axis_data = pd.concat([one,two], axis=1)
axis_data
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
#Merge in Pandas
reg = pd.DataFrame({'reg':[1,2,3,4], 'name':['Andrew','Chioma','Tochi','Princess']})
logins = pd.DataFrame({'login':[1,2,3,4], 'name':['Ekundayo','Andrew','Bola','Princess']})

# %%
reg
# Out:
#    reg      name
# 0    1    Andrew
# 1    2    Chioma
# 2    3     Tochi
# 3    4  Princess

# %%
logins
# Out:
#    login      name
# 0      1  Ekundayo
# 1      2    Andrew
# 2      3      Bola
# 3      4  Princess

# %%
#Inner Join - What is common to both data

left_join_data = pd.merge(reg, logins, how='inner')
left_join_data
# Out:
#    reg      name  login
# 0    1    Andrew      2
# 1    4  Princess      4

# %%
#Left Join - What is common to both data + values in the left

inner_join_data = pd.merge(reg, logins, how='left')
inner_join_data
# Out:
#    reg      name  login
# 0    1    Andrew    2.0
# 1    2    Chioma    NaN
# 2    3     Tochi    NaN
# 3    4  Princess    4.0

# %%
#Right Join - What is common to both data + values in the right

right_join_data = pd.merge(reg, logins, how='right')
right_join_data
# Out:
#    reg      name  login
# 0  NaN  Ekundayo      1
# 1  1.0    Andrew      2
# 2  NaN      Bola      3
# 3  4.0  Princess      4

# %%
#Outer Join - The combination of right and left data

outer_join_data = pd.merge(reg, logins, how='outer')
outer_join_data
# Out:
#    reg      name  login
# 0  1.0    Andrew    2.0
# 1  2.0    Chioma    NaN
# 2  3.0     Tochi    NaN
# 3  4.0  Princess    4.0
# 4  NaN  Ekundayo    1.0
# 5  NaN      Bola    3.0
