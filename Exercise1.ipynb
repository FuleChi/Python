# %% [markdown]
# <a href="https://colab.research.google.com/github/FuleChi/Python/blob/main/Exercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Statistiques données
minimum = 10
Q1 = 70
median = 90
Q3 = 110
maximum = 170

# Création du boxplot
fig, ax = plt.subplots(figsize=(8, 6))
ax.boxplot([[minimum, Q1, median, Q3, maximum]], vert=False, patch_artist=True,
           boxprops=dict(facecolor='lightblue', color='blue'),
           whiskerprops=dict(color='blue'),
           capprops=dict(color='blue'),
           medianprops=dict(color='red'))

# Ajouter des détails au graphique
ax.set_title("Boxplot basé sur des statistiques", fontsize=14)
ax.set_xlabel("Temps (minutes)", fontsize=12)
ax.set_yticklabels(["Données"])
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Afficher le graphique
plt.show()
